# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from utils import *

# %%
img = cv2.imread('detail.jpg', 0)

# %%
plt.figure(figsize=(20, 20))
plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(make_spectrum(img), cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ## Идеальный фильтр

# %%
m, im = perfect_filter_blur(img, 15)
plt.figure(figsize=(20, 20))
plt.subplot(141),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(142),plt.imshow(im, cmap = 'gray')
plt.title('Perfect blur'), plt.xticks([]), plt.yticks([])
plt.subplot(143),plt.imshow(m, cmap = 'gray')
plt.title('Filter'), plt.xticks([]), plt.yticks([])
plt.subplot(144),plt.imshow(make_spectrum(im), cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
m, im = perfect_filter_sharpness(img, 10)
plt.figure(figsize=(20, 20))
plt.subplot(141),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(142),plt.imshow(im, cmap = 'gray')
plt.title('Perfect sharpness'), plt.xticks([]), plt.yticks([])
plt.subplot(143),plt.imshow(m, cmap = 'gray')
plt.title('Filter'), plt.xticks([]), plt.yticks([])
plt.subplot(144),plt.imshow(make_spectrum(im), cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ## Фильтр Батерворта

# %%
m, im = butterworth_filter_blur(img, 30, 3)
plt.figure(figsize=(20, 20))
plt.subplot(141),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(142),plt.imshow(im, cmap = 'gray')
plt.title('Butterworth blur'), plt.xticks([]), plt.yticks([])
plt.subplot(143),plt.imshow(m, cmap = 'gray')
plt.title('Filter'), plt.xticks([]), plt.yticks([])
plt.subplot(144),plt.imshow(make_spectrum(im), cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
m, im = butterworth_filter_sharpness(img, 20, 3)
plt.figure(figsize=(20, 20))
plt.subplot(141),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(142),plt.imshow(im, cmap = 'gray')
plt.title('Butterworth sharpness'), plt.xticks([]), plt.yticks([])
plt.subplot(143),plt.imshow(m, cmap = 'gray')
plt.title('Filter'), plt.xticks([]), plt.yticks([])
plt.subplot(144),plt.imshow(make_spectrum(im), cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ## Гауссиан

# %%
m, im = gaussian_filter_blur(img, 30)
plt.figure(figsize=(20, 20))
plt.subplot(141),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(142),plt.imshow(im, cmap = 'gray')
plt.title('Gaussian blur'), plt.xticks([]), plt.yticks([])
plt.subplot(143),plt.imshow(m, cmap = 'gray')
plt.title('Filter'), plt.xticks([]), plt.yticks([])
plt.subplot(144),plt.imshow(make_spectrum(im), cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
m, im = gaussian_filter_sharpness(img, 10)
plt.figure(figsize=(20, 20))
plt.subplot(141),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(142),plt.imshow(im, cmap = 'gray')
plt.title('Gaussian sharpness'), plt.xticks([]), plt.yticks([])
plt.subplot(143),plt.imshow(m, cmap = 'gray')
plt.title('Filter'), plt.xticks([]), plt.yticks([])
plt.subplot(144),plt.imshow(make_spectrum(im), cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()
